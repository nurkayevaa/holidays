# %%
from matplotlib import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import math
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

r = T = np.arange(0, 2*pi, 0.01)
r, T = np.meshgrid(r, T)
#Parametrise it
X = r*np.cos(T)/6
X2 = r*np.cos(T)/4
X3 = r*np.cos(T)/3
Y = r*np.sin(T)/6
Y2 = r*np.sin(T)/4
Y3 = r*np.sin(T)/3
Z = -2*r**2
Z2 = -2*r**2- 80
Z3 = -2*r**2- 160





zdata = -25 * np.random.random(50)
zdatag = -250 * np.random.random(50)
xdata = np.sin(zdata) + 0.08 * np.random.randn(50)
xdatag = 0.5*np.sin(zdata) + 0.08 * np.random.randn(50)
ydata = 2*np.cos(zdata) + 0.09* np.random.randn(50)
ydatag = np.cos(zdata) + 0.09* np.random.randn(50)

ax.plot_surface(X, Y, Z,  alpha=0.9, rstride=10, cstride=10, linewidth=0.5, cmap=cm.summer)
ax.plot_surface(X2, Y2, Z2,  alpha=0.9, rstride=10, cstride=10, linewidth=0.5, cmap=cm.summer)
ax.plot_surface(X3, Y3, Z3,  alpha=0.9, rstride=10, cstride=10, linewidth=0.5, cmap=cm.summer)
ax.scatter3D(xdatag, ydatag, zdata, c=zdata,  cmap='hot');
ax.scatter3D(xdata, ydata, zdatag, c=zdata,  cmap='cool');




x =[0]
y =[0]
x1 =[0.01]
y1 =[-0.01]
z =[40]



ax.scatter(x1, y1, z, c='w', marker=(5, 1), s = 600)
ax.scatter(x, y, z, c='r', marker=(5, 1), s = 800)
plt.show()
